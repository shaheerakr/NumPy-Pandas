# %%
import pandas as pd

# %%
data = pd.read_csv("C:\Work\Machine learning\Datasets\clustring\Mall_Customers.csv",index_col="CustomerID")

# %%
data.head()
# Out:
#              Genre  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40

# %%
data[data.Age > 25]
# Out:
#              Genre  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 5           Female   31                  17                      40
# 7           Female   35                  18                       6
# 9             Male   64                  19                       3
# 10          Female   30                  19                      72
# 11            Male   67                  19                      14
# 12          Female   35                  19                      99
# 13          Female   58                  20                      15
# 15            Male   37                  20                      13
# 17          Female   35                  21                      35
# 19            Male   52                  23                      29
# 20          Female   35                  23                      98
# 21            Male   35                  24                      35
# 23          Female   46                  25                       5
# ...

# %%
data.columns
# Out:
# Index(['Genre', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')

# %%
len(data)
# Out:
# 200

# %%
data.iloc[4]
# Out:
# Genre                     Female
# Age                           31
# Annual Income (k$)            17
# Spending Score (1-100)        40
# Name: 5, dtype: object

# %%
data
# Out:
#              Genre  Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 1             Male   19                  15                      39
# 2             Male   21                  15                      81
# 3           Female   20                  16                       6
# 4           Female   23                  16                      77
# 5           Female   31                  17                      40
# 6           Female   22                  17                      76
# 7           Female   35                  18                       6
# 8           Female   23                  18                      94
# 9             Male   64                  19                       3
# 10          Female   30                  19                      72
# 11            Male   67                  19                      14
# 12          Female   35                  19                      99
# 13          Female   58                  20                      15
# ...

# %%
data.groupby(["Genre"]).count()
# Out:
#         Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female  112                 112                     112
# Male     88                  88                      88

# %%
data.groupby(['Age'])

# %%
sum(data.Age == 30) #this will return all ages that are 30
# Out:
# 7

# %%
len(data.Age == 30)#this will return all
# Out:
# 200

# %%
data1 = data.loc[0:10,"Genre":"Age"]

# %%
data1
# Out:
#              Genre  Age
# CustomerID
# 1             Male   19
# 2             Male   21
# 3           Female   20
# 4           Female   23
# 5           Female   31
# 6           Female   22
# 7           Female   35
# 8           Female   23
# 9             Male   64
# 10          Female   30

# %%
import numpy as np
data.iloc[4:10,:]=np.nan
# Out:
# C:\Users\Shaheer Akram\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data = data.dropna(how = 'na')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-78e2b72049fd> in <module>()
# ----> 1 data = data.dropna(how = 'nan')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    3500             else:
#    3501                 if how is not None:
# -> 3502                     raise ValueError('invalid how option: %s' % how)
#    3503                 else:
#    3504                     raise TypeError('must specify how or thresh')
#
# ValueError: invalid how option: nan

# %%
data
# Out:
#              Genre   Age  Annual Income (k$)  Spending Score (1-100)
# CustomerID
# 4           Female  23.0                16.0                    77.0
# 5           Female  31.0                17.0                    40.0
# 6           Female  22.0                17.0                    76.0
# 7           Female  35.0                18.0                     6.0
# 8           Female  23.0                18.0                    94.0
# 9             Male  64.0                19.0                     3.0
# 10          Female  30.0                19.0                    72.0
# 11            Male  67.0                19.0                    14.0
# 12          Female  35.0                19.0                    99.0
# 13          Female  58.0                20.0                    15.0
# 14          Female  24.0                20.0                    77.0
# 15            Male  37.0                20.0                    13.0
# ...

# %%
school = pd.read_csv("school.csv")

# %%
school.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
school[(school["Student Name"].str.startswith("A"))&(school["Grade"]=="A")]
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 7                9           8.0          10.0                   10
# 9                8           8.0           NaN                    8
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 7                    45        40.0           85     A
# 9                    44        40.0           84     A

# %%
school.columns
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
data2 = school[school["Grade"]=="A"]

# %%
data2.loc[:,"Quiz 1":"Quiz 2"]
# Out:
#     Quiz 1  Quiz 2
# 7      9.0     6.0
# 9      8.0     6.0
# 10     8.0     7.0
# 19     9.0     6.0
# 25     9.0     6.0
# 34     9.0     6.0
# 40     9.0     6.0
# 45     9.0     6.0

# %%
def a(age):
    if age<18:
        return "Non-Adult"
    else:
        return "Adult"

# %%
persons = pd.data
