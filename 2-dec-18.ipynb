# %%
import pandas as pd

# %%
data = pd.read_csv("C:\Work\Machine learning\Datasets\Election data 2018.csv")

# %%
data.head()
# Out:
#   District     Seat Constituency_title                     Candidate_Name  \
# 0  Chitral  Chitral               NA-1                   lftikhar ud Din
# 1  Chitral  Chitral               NA-1                      Taqdira Ajmal
# 2  Chitral  Chitral               NA-1                    Saeed Ur Rehman
# 3  Chitral  Chitral               NA-1                        Saleem Khan
# 4  Chitral  Chitral               NA-1  Shahzada Muharamad Taimur Khisrao
#
#                                      Party
# 0                Pakistan Muslim League(N)
# 1                              Independent
# 2                  Pakistan Rah-e-Haq Part
# 3  Pakistan Peoples Party Parliamentarians
# 4                              Independent

# %%
data
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
data[data.Constituency_title == "NA-256"]
# Out:
#       District                Seat Constituency_title  \
# 2867  Karachi   Karachi Central-IV             NA-256
# 2868  Karachi   Karachi Central-IV             NA-256
# 2869  Karachi   Karachi Central-IV             NA-256
# 2870  Karachi   Karachi Central-IV             NA-256
# 2871  Karachi   Karachi Central-IV             NA-256
# 2872  Karachi   Karachi Central-IV             NA-256
# 2873  Karachi   Karachi Central-IV             NA-256
# 2874  Karachi   Karachi Central-IV             NA-256
# 2875  Karachi   Karachi Central-IV             NA-256
# 2876  Karachi   Karachi Central-IV             NA-256
# 2877  Karachi   Karachi Central-IV             NA-256
# 2878  Karachi   Karachi Central-IV             NA-256
# 2879  Karachi   Karachi Central-IV             NA-256
# 2880  Karachi   Karachi Central-IV             NA-256
# 2881  Karachi   Karachi Central-IV             NA-256
# 2882  Karachi   Karachi Central-IV             NA-256
#
# ...

# %%
data[data.Constituency_title == "NA-256"].count()
# Out:
# District              16
# Seat                  16
# Constituency_title    16
# Candidate_Name        16
# Party                 16
# dtype: int64

# %%
data[(data.Candidate_Name == "Imran Ahmed Khan Niazi")& (data.Party == "Pakistan Tehreek-e-Insaaf")]
# Out:
#       District          Seat Constituency_title          Candidate_Name  \
# 725  Islamabad  Islamabad-II              NA-53  Imran Ahmed Khan Niazi
#
#                          Party
# 725  Pakistan Tehreek-e-Insaaf

# %%
data[(data.Candidate_Name.str.startswith("Imran"))|(data.Candidate_Name.str.startswith("imran"))]
# Out:
#           District             Seat Constituency_title  \
# 207          Swabi          Swabi-2              NA-19
# 259       Nowshera       Nowshera-2              NA-26
# 357          Bannu            Bannu              NA-35
# 370   Lakki Marwat     Lakki marwat              NA-36
# 507    Tribal Area    Tribal Area-5              NA-44
# 725      Islamabad     Islamabad-II              NA-53
# 861        Chakwal        Chakwal-I              NA-64
# 956        Sialkot       Sialkot-II              NA-73
# 1204      Mianwali       Mianwali-l              NA-95
# 1545         Kasur         Kasur-II             NA-138
# 2667      Karachi   Karachi East-II             NA-243
#
#                Candidate_Name                                   Party
# 207               Imran Ullah              Pakistan Muslim League (N)
# 259              Imran Khatak                Pakistan Tehreek-e-lnsaf
# 357    Imran Ahmed Khan Niazi                 Pakistan teheek-e-Insaf
# ...

# %%
def a(age):
    if age<18:
        return "Non-Adult"
    else:
        return "Adult"

# %%
persons = pd.DataFrame({
    "name":"shahzad",
    "age":"18",
    "percent":"87"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-6dd9e936b22b> in <module>()
#       2     "name":"shahzad",
#       3     "age":"18",
# ----> 4     "percent":"87"})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
# ...

# %%
def resolveParty(x):
    max = 0
    match =''
    for i in data["party"]:
        r = f.ratio(x,i)
        if(r>max)
# Out:
#   File "<ipython-input-33-498e4426666c>", line 6
#     if(r>max)
#              ^
# SyntaxError: invalid syntax
